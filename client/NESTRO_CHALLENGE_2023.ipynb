# %%
import pandas as pd

# %%
ds = pd.read_csv("Приложение 2. Данные о потоке нефти, газа и воды по каждому трубопроводу.xlsx - Данные для кейса.csv")

# %%
ds.head()
# Out:
#       № Наименование трубопровода   Ø, мм Толщина стенки, мм  Длина, м вход   \
# 0  24.0                      A-B4  323,80               18,7    3130.0  2,13
# 1  17.0               C2/D2-I3/E   426,00               16,4    2970.0  1,88
# 2  25.0                     B4-B5  323,80               13,7    5600.0  1,56
# 3   1.0                    F1-D14  323,80                 16    5952.0   3,1
# 4  15.0                     G6-G4  325,00               13,7    1284.0  3,12
#
#   выход   Qн, т/сут 2014  Qн, т/сут2015  Qн, т/сут2016  ...  \
# 0   1,63           677.0          472.0          439.0  ...
# 1   1,46          2714.0         2352.0         2472.0  ...
# 2   1,28           873.0          740.0          692.0  ...
# 3   2,63           386.0          343.0          310.0  ...
# 4    3,1           925.0          910.0          499.0  ...
#
#    Рср. кон.точка тр/да 2014  Рср. кон.точка тр/да 2015  \
# 0                       18,6                       19,1
# ...

# %%
ds.head()
# Out:
#       № Наименование трубопровода   Ø, мм Толщина стенки, мм  Длина, м вход   \
# 0  24.0                      A-B4  323,80               18,7    3130.0  2,13
# 1  17.0               C2/D2-I3/E   426,00               16,4    2970.0  1,88
# 2  25.0                     B4-B5  323,80               13,7    5600.0  1,56
# 3   1.0                    F1-D14  323,80                 16    5952.0   3,1
# 4  15.0                     G6-G4  325,00               13,7    1284.0  3,12
#
#   выход   Qн, т/сут2014  Qн, т/сут2015  Qн, т/сут2016  ...  \
# 0   1,63          677.0          472.0          439.0  ...
# 1   1,46         2714.0         2352.0         2472.0  ...
# 2   1,28          873.0          740.0          692.0  ...
# 3   2,63          386.0          343.0          310.0  ...
# 4    3,1          925.0          910.0          499.0  ...
#
#    Рср. кон.точка тр/да 2014  Рср. кон.точка тр/да 2015  \
# 0                       18,6                       19,1
# ...

# %%
type(ds)
# Out:
# pandas.core.frame.DataFrame

# %%
ds.head()
# Out:
#   Unnamed: 0   Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 2        NaN          NaN        NaN        NaN        NaN        NaN
# 3        NaN          NaN        NaN        NaN        NaN        NaN
# 4         24         A-B4      323.8       18.7       3130       2.13
# 5         17  C2/D2-I3/E         426       16.4       2970       1.88
# 6         25        B4-B5      323.8       13.7       5600       1.56
#
#   Unnamed: 6 Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  Unnamed: 78  \
# 2        NaN       2014      2015.0      2016.0  ...       2015.0
# 3        NaN        NaN         NaN         NaN  ...          NaN
# 4       1.63        677       472.0       439.0  ...         19.1
# 5       1.46       2714      2352.0      2472.0  ...         15.2
# 6       1.28        873       740.0       692.0  ...         14.9
#
#    Unnamed: 79  Unnamed: 80  Unnamed: 81  Unnamed: 82  Unnamed: 83  \
# 2       2016.0       2017.0       2018.0       2019.0       2020.0
# ...

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 87 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   №                                              40 non-null     float64
#  1   Наименование трубопровода                      48 non-null     object
#  2   Ø, мм                                          48 non-null     object
#  3   Толщина стенки, мм                             48 non-null     object
#  4   Длина, м                                       48 non-null     float64
#  5   вход                                           48 non-null     object
#  6   выход                                          48 non-null     object
#  7   Qн, т/сут2014                                  48 non-null     float64
#  8   Qн, т/сут2015                                  48 non-null     float64
# ...

# %%
ds.isna().sum().sum()
# Out:
# 439

# %%
ds.dtypes
# Out:
# №                            float64
# Наименование трубопровода     object
# Ø, мм                         object
# Толщина стенки, мм            object
# Длина, м                     float64
#                               ...
# Рср. кон.точка тр/да 2019     object
# Рср. кон.точка тр/да 2020     object
# Рср. кон.точка тр/да 2021     object
# Рср. кон.точка тр/да 2022     object
# Рср. кон.точка тр/да 2023     object
# Length: 87, dtype: object

# %%
ds.shape
# Out:
# (51, 87)

# %%
ds["W, % 2022"]
# Out:
# 0     110.0
# 1      60.0
# 2      76.0
# 3      25.0
# 4      78.0
# 5      89.0
# 6      91.0
# 7      79.0
# 8     110.0
# 9      72.0
# 10     65.0
# 11     30.0
# 12    106.0
# 13      6.0
# 14     60.0
# 15      2.0
# 16     92.0
# 17      4.0
# 18     16.0
# 19     73.0
# 20    122.0
# 21     89.0
# 22     61.0
# 23     54.0
# 24     90.0
# 25    110.0
# 26     42.0
# 27     60.0
# 28     51.0
# 29    106.0
# 30     88.0
# 31     39.0
# 32     30.0
# 33     74.0
# 34     17.0
# 35     73.0
# 36     81.0
# 37     62.0
# 38     90.0
# 39    120.0
# 40      1.0
# 41     60.0
# 42      0.0
# 43     54.0
# 44     40.0
# 45     34.0
# 46     63.0
# 47     37.0
# 48      NaN
# 49      NaN
# 50      NaN
# Name: W, % 2022, dtype: float64
